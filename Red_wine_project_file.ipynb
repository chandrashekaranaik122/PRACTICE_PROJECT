# %% [markdown]
# # RED WINE PROJECT

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# import the nessasary library such as pandas , numpy,seaborn,matplot and import the warnings also

# %%
df=pd.read_csv('Red_wine.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# imported the red wine csv file from my jupyter notebook

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# there are 12 columns present in my dataset and they are .....
#
# 1.fixed acidity
#
# 2.volatile acidity
#
# 3.citric acid
#
# 4.residual sugar
#
# 5.chlorides
#
# 6.free sulfur dioxide
#
# 7.total sulfur dioxide
#
# 8.density
#
# 9.pH
#
# 10.sulphates
#
# 11.alcohol
#
# 12.quality

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# The dataset contains 2 types of data and  they are integer and float datatype

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# there is no missing the present in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# the dataset contains 12 columns and 1599 rows..
# there are 11 columns are having float datatype and only one column having the integer datatype

# %%
df.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %% [markdown]
# sepearating the columns into list

# %%
df['fixed acidity']
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 1599, dtype: float64

# %% [markdown]
# the fixed acidity column has contineous data and the values , there 1599 entris are there and having float data

# %%
plt.figure(figsize=(15,5),)
sns.heatmap(df.isnull(),cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# there is no missing data present in the dataset ......

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
#
#
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
#
#
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
#
#
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64
#
#
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# ...

# %% [markdown]
# all the 12 columns having data and  there is no missing value in any rows and columns

# %%
k=df.describe()
k
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# we are having the statistical values of the dataset
#
# the count of every is columns are 1599 entries......
#
# the mean is greater than median in every column this confirms that Right skewed data is present.....
#
# in some columns outliers are present as we obserb, 'residual sugar','free sulfer dioxide 'and 'total sulfer dioxide' there is
# huge difference in 3rd Quartile and maximum value , it means we need to clean the outliers

# %%
plt.figure(figsize=(20,5))
sns.heatmap(data=k,fmt='0.2f',annot=True,linecolor='black',linewidth=0.2,cmap='Accent')
# Out:
# <AxesSubplot:>

# %% [markdown]
# in the graph also we can see the huge difference in value in 'total sulfer dioxide ' column

# %% [markdown]
# # Data Visialization

# %%
sns.scatterplot(data=df,x='fixed acidity',y='residual sugar',hue='quality')
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='residual sugar'>

# %%
sns.lineplot(data=df,x='volatile acidity',y='fixed acidity')
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='fixed acidity'>

# %%
sns.countplot(data=df,x='quality')
print(df['quality'].value_counts())
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# from the above graph we analysie the qaulity column having different values for each quality , the data is not ditrubuted equaly for each quality

# %%
sns.scatterplot(data=df,x='fixed acidity',y='volatile acidity',palette='prism')
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='volatile acidity'>

# %% [markdown]
# fixed acidity and volatile acidity are positively corelated as the fixed acidity incereses the volatile acidity also increses

# %%
sns.scatterplot(data=df,x='citric acid',y='residual sugar')
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='residual sugar'>

# %% [markdown]
# here also we can see a positive reletion between the citric acid and residual sugar

# %%
sns.scatterplot(data=df,x='citric acid',hue='quality',y='free sulfur dioxide')
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='free sulfur dioxide'>

# %%
plt.figure(figsize=(30,20),facecolor='red')
sns.pairplot(data=df,hue='quality',palette='Dark2')

# %%
cor=df.corr()

# %%
cor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# here we applied the corr() function to find the co reletion of the dataset

# %%
plt.figure(figsize=(20,8),facecolor='yellow')
sns.heatmap(data=cor,annot=True,fmt='0.2f',linecolor='black',linewidth=0.2,cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# here we can see the coreletion of the variables with the target...
#
# 1.volatile acidity,total sulfur dioxide,density and chlorides columns are negative reletion with the quality
#
#
# 2.alcohol,sulphates,citric acid are highly co releted to the quality column
#
#
# 3.volatile acidity and total sulfur dioxide are higly negative impact on quality of the wine we sort the columns from dataset

# %%
cor['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64

# %% [markdown]
# analysing the co reletion of the target with input variables ....
#
# 'alcohol' column highly positive co releted with quality of wine and 'volatile acidity ' highly negative co reletion with the quality

# %%
plt.figure(figsize=(20,8))
df.corr()['quality'].sort_values(ascending=False).drop(['quality']).plot(kind='bar',color='k')
plt.xlabel('Feature',fontsize=45)
plt.ylabel('Target',fontsize=45)
plt.title('Correletion b/w Feature and Target',fontsize=45)
plt.show()

# %% [markdown]
# in graph we can see the same thing as mentined the co reletion by graphically

# %%
sns.distplot(df['alcohol'])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# We are using the distplot to check the skewness of the columns......
#
# In alcohol column we can see the data is right skewed ,here we have remove the skewed the data

# %%
sns.distplot(df['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %% [markdown]
# In 'fixed acidity' column there is no skewed data is present , the data equally distributed

# %%
sns.distplot(df['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %% [markdown]
# Here also a slight skewed data present

# %%
sns.distplot(df['residual sugar'])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %% [markdown]
# 'residual sugar 'column having right skewed data......

# %%
sns.boxplot(data=df['fixed acidity'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# using boxplot we can check the outlairs in the columns
#
# here we can clearly see the outlairs present in the fixed acidity column

# %%
plt.figure(figsize=(15,25),facecolor='w')
p=1
for i in df:
    if p<=15:
        plt.subplot(5,3,p)
        sns.boxplot(data=df[i],palette='tab10')
        plt.xlabel('-')
        plt.ylabel(i)
    p+=1
plt.show()

# %% [markdown]
# boxplots of each graph showing clearly that all the columns are having outliers so we have to remove all the outliers

# %% [markdown]
# # TO Remove the outliers we are using the Zscore method

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.528360          0.961877     1.391472        0.453218   0.243707
# 1          0.298547          1.967442     1.391472        0.043416   0.223875
# 2          0.298547          1.297065     1.186070        0.169427   0.096353
# 3          1.654856          1.384443     1.484154        0.453218   0.264960
# 4          0.528360          0.961877     1.391472        0.453218   0.243707
# ...             ...               ...          ...             ...        ...
# 1594       1.217796          0.403229     0.980669        0.382271   0.053845
# 1595       1.390155          0.123905     0.877968        0.240375   0.541259
# 1596       1.160343          0.099554     0.723916        0.169427   0.243707
# 1597       1.390155          0.654620     0.775267        0.382271   0.264960
# 1598       1.332702          1.216849     1.021999        0.752894   0.434990
#
# ...

# %% [markdown]
# importing the zscore from scientific python, using numpy absolute function for removing the outlairs

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#          45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#         106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#         151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#         244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#         354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#         459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#         555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#         639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#         690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#         821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#         982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#        1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
# ...

# %% [markdown]
# we are setting the threshold to 3 , because 99% of the data is present in the range of 3 standard deviations and
# rest data having outliers we have remove that data

# %%
z.iloc[13][9]
# Out:
# 5.32210116796055

# %% [markdown]
# we can confirm using the iloc function its showing 5.3 means outlier

# %%
z.iloc[1589][3]
# Out:
# 3.732701384742145

# %% [markdown]
# here also outlier present

# %%
df1=df[(z<3).all(axis=1)]
print(df1.shape)
print(df.shape)
# Out:
# (1451, 12)
# (1599, 12)

# %% [markdown]
# creating new dataset df1 , selecting the data z value less than 3 and rest of the leaving .....
#
# df1 dataset shows there are 1451 rows and 12 columns present
#
# df dataset shows 1599 rows and 12 columns
#
# we confirm that the outliers are removed from the dataset

# %%
print('Data loss percentage ',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss percentage  9.255784865540964

# %% [markdown]
# the percentage of data loss is less than 10% so we can proced further

# %%
plt.figure(figsize=(15,25),facecolor='red')
p=1
for i in df1:
    if p<=15:
        plt.subplot(5,3,p)
        sns.boxplot(data=df1[i],palette='tab10')
        plt.xlabel('-')
        plt.ylabel(i)
    p+=1
plt.show()

# %% [markdown]
# still there are some columns are having the outliers we can drop some columns,
#
# 1) residual sugar
#
# 2) chlorides

# %%
df1=df1.drop(['residual sugar'],axis=1)
df1=df1.drop(['chlorides'],axis=1)

# %% [markdown]
# removing the columns which are having still outliers

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  free sulfur dioxide  \
# 0               7.4             0.700         0.00                 11.0
# 1               7.8             0.880         0.00                 25.0
# 2               7.8             0.760         0.04                 15.0
# 3              11.2             0.280         0.56                 17.0
# 4               7.4             0.700         0.00                 11.0
# ...             ...               ...          ...                  ...
# 1594            6.2             0.600         0.08                 32.0
# 1595            5.9             0.550         0.10                 39.0
# 1596            6.3             0.510         0.13                 29.0
# 1597            5.9             0.645         0.12                 32.0
# 1598            6.0             0.310         0.47                 18.0
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality
# ...

# %% [markdown]
# after removing the columns dataset having 1451 rows and 10 columns

# %%
df1.skew()
# Out:
# fixed acidity           0.823934
# volatile acidity        0.380659
# citric acid             0.291297
# free sulfur dioxide     0.869250
# total sulfur dioxide    1.183161
# density                 0.055738
# pH                      0.114705
# sulphates               0.891492
# alcohol                 0.758958
# quality                 0.407865
# dtype: float64

# %%
df1.corr().quality.sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.501501
# sulphates               0.386567
# citric acid             0.243999
# fixed acidity           0.145163
# free sulfur dioxide    -0.071202
# pH                     -0.082164
# density                -0.167568
# total sulfur dioxide   -0.237745
# volatile acidity       -0.353443
# Name: quality, dtype: float64

# %% [markdown]
# skewness of each column with respect to the quality column ...
#
# the acceptance range of skewness is +0.5 to -0.5 it shows data present dataset is in accepted..

# %%
df=df1
df.shape
# Out:
# (1451, 10)

# %% [markdown]
# again saving the df1 as df

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %% [markdown]
# separating the x and y data from the dataset using the pandas iloc function

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  free sulfur dioxide  \
# 0               7.4             0.700         0.00                 11.0
# 1               7.8             0.880         0.00                 25.0
# 2               7.8             0.760         0.04                 15.0
# 3              11.2             0.280         0.56                 17.0
# 4               7.4             0.700         0.00                 11.0
# ...             ...               ...          ...                  ...
# 1594            6.2             0.600         0.08                 32.0
# 1595            5.9             0.550         0.10                 39.0
# 1596            6.3             0.510         0.13                 29.0
# 1597            5.9             0.645         0.12                 32.0
# 1598            6.0             0.310         0.47                 18.0
#
#       total sulfur dioxide  density    pH  sulphates  alcohol
# ...

# %%
print(y.shape)
print(x.shape)
# Out:
# (1451,)
# (1451, 9)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  free sulfur dioxide  \
# 0         -0.552930          1.050914    -1.390400            -0.441060
# 1         -0.309900          2.119336    -1.390400             1.063255
# 2         -0.309900          1.407054    -1.180831            -0.011256
# 3          1.755851         -1.442071     1.543569             0.203646
# 4         -0.552930          1.050914    -1.390400            -0.441060
# ...             ...               ...          ...                  ...
# 1446      -1.282019          0.457346    -0.971261             1.815413
# 1447      -1.464291          0.160562    -0.866477             2.567570
# 1448      -1.221261         -0.076865    -0.709300             1.493059
# 1449      -1.464291          0.724451    -0.761692             1.815413
# 1450      -1.403533         -1.264001     1.072038             0.311097
#
#       total sulfur dioxide   density        pH  sulphates   alcohol
# ...

# %% [markdown]
# applying standard scaler technique to standardize the distribution with zero mean and standrd deviation -1 to +1

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns

vif
# Out:
#    VIF values              Features
# 0    6.726355         fixed acidity
# 1    1.845263      volatile acidity
# 2    3.175538           citric acid
# 3    1.929624   free sulfur dioxide
# 4    2.173106  total sulfur dioxide
# 5    4.218933               density
# 6    2.889483                    pH
# 7    1.291912             sulphates
# 8    2.308915               alcohol

# %% [markdown]
# using the vif factor to find is there any multicolinearity is present in the data set

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1451, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %% [markdown]
# the target column has different types of quality but the quality of each columns are not equal so here apply the SMOTE function...
# to equal the each quality should contains same number of values

# %%
sm=SMOTE()

# %%
x,y=sm.fit_resample(x,y)

# %% [markdown]
# applying the SMOTE function on x and y

# %%
y.value_counts()
# Out:
# 5    617
# 6    617
# 7    617
# 4    617
# 8    617
# Name: quality, dtype: int64

# %% [markdown]
# Each quality has equal number in values now predict data

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve

# %% [markdown]
# from sklearn we have to import nessasery train ,test , split model to separate the data for train & test ...
#
# import Decisiontreeclassifier for predict the target values
#
# since its Classifiction problem so we can import classification report ,accuracy_score & confusion matrix

# %%
dtc=DecisionTreeClassifier()

# %%
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier

# %% [markdown]
# also import the other models also Gradient,Ada,Bagging classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
maxAccu=0
maxRs=0
for i in range(1,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    RFR=RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print("Best Accuracy is", maxAccu,"at random_state ",maxRs)
# Out:
# Best Accuracy is 0.8779697624190065 at random_state  322

# %% [markdown]
# we are passing the train data through the Randomforestclassifier to find the Random state for the model..
#
# from this we find best Random state value is 355

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=355)

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.svm import SVC

# %%
print('Decision Tree classifier')
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
preddtc=dtc.predict(x_test)
preddtc_train=dtc.predict(x_train)
print('accuracy_score on test data',accuracy_score(y_test,preddtc)*100)
print('accuracy_score on train data',accuracy_score(y_train,preddtc_train)*100)
# Out:
# Decision Tree classifier
# accuracy_score on test data 76.99784017278618
# accuracy_score on train data 100.0

# %% [markdown]
# using the Decision tree classifier
#
# the model working Good on train data but on test data its working 79% only

# %%
print('Support vector mission')
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
predsvc_train=svc.predict(x_train)
print('accuracy_score on test data',accuracy_score(y_test,predsvc)*100)
print('accuracy_score on train data',accuracy_score(y_train,predsvc_train)*100)
# Out:
# Support vector mission
# accuracy_score on test data 71.05831533477321
# accuracy_score on train data 73.73784159333024

# %% [markdown]
# using the support vector mission
#
# the model working nearly same on both train and test data

# %%
print('Ada boost Classifier')
Ad=AdaBoostClassifier()
Ad.fit(x_train,y_train)
predad=Ad.predict(x_test)
predad_train=Ad.predict(x_train)
print('accuracy_score on test data',accuracy_score(y_test,predad)*100)
print('accuracy_score on train data',accuracy_score(y_train,predad_train)*100)
# Out:
# Ada boost Classifier
# accuracy_score on test data 45.57235421166307
# accuracy_score on train data 46.17878647522001

# %% [markdown]
# Adaboostingclassifier is not working good on my dataset
#
# here the accuracy is just 40%

# %%
print('ExtraTreesClassifier')
et=ExtraTreesClassifier()
et.fit(x_train,y_train)
predet=et.predict(x_test)
predet_train=et.predict(x_train)
print('accuracy_score on test data',accuracy_score(y_test,predet)*100)
print('accuracy_score on train data',accuracy_score(y_train,predet_train)*100)
# Out:
# ExtraTreesClassifier
# accuracy_score on test data 87.79697624190065
# accuracy_score on train data 100.0

# %% [markdown]
# Extratrees classifier is working good on dataset
#
# we can see here accurcy is 88% on test data

# %%
print('BaggingClassifier')
bg=DecisionTreeClassifier()
bg.fit(x_train,y_train)
predbg=bg.predict(x_test)
predbg_train=bg.predict(x_train)
print('accuracy_score on test data',accuracy_score(y_test,predbg)*100)
print('accuracy_score on train data',accuracy_score(y_train,predbg_train)*100)
# Out:
# BaggingClassifier
# accuracy_score on test data 76.67386609071274
# accuracy_score on train data 100.0

# %% [markdown]
# bagging classifier is not working upto the mark on test data

# %%
print('GradinetBoostingClassifier')
gd=GradientBoostingClassifier()
gd.fit(x_train,y_train)
predgd=gd.predict(x_test)
predgd_train=gd.predict(x_train)
print('accuracy_score on test data',accuracy_score(y_test,predgd)*100)
print('accuracy_score on train data',accuracy_score(y_train,predgd_train)*100)
# Out:
# GradinetBoostingClassifier
# accuracy_score on test data 79.48164146868251
# accuracy_score on train data 90.92172301991663

# %% [markdown]
# Gradientboosting classifier is also working good on the test and train data

# %%
print('RandomForestClassifier')
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
predrf_train=rf.predict(x_train)
print('accuracy score on test data',accuracy_score(y_test,predrf)*100)
print('accuracy_score on train data',accuracy_score(y_train,predrf_train)*100)
# Out:
# RandomForestClassifier
# accuracy score on test data 85.85313174946005
# accuracy_score on train data 100.0

# %% [markdown]
# RandomForestclassifier also working good on my train and test data

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# To avoid the overfitting and underfitting of data we are using the cross validation score ...
#
# it will helps to overcome from the above problem

# %%
print('Decision Tree classifier')
scoredt=cross_val_score(dtc,x,y,cv=5)
print('Mean score is ',scoredt.mean()*100)
print('Accuracy_score is ',accuracy_score(y_test,preddtc)*100)
print('Difference b/w accuracy score and cross validation score is ', (accuracy_score(y_test,preddtc)-scoredt.mean())*100)
print('\n')

print('Support vector mission')
scoresv=cross_val_score(svc,x,y)
print('Mean score is ',scoresv.mean()*100)
print('Accuracy score is ',accuracy_score(y_test,predsvc)*100)
print('Difference b/w accuracy score and cross validation score is ', (accuracy_score(y_test,predsvc)-scoresv.mean())*100)
print('\n')

print('GradientBoostingClassifier')
scoregd=cross_val_score(gd,x,y)
print('Mean score is ',scoregd.mean()*100)
print('Accuracy score is ',accuracy_score(y_test,predgd)*100)
print('Difference b/w accuracy score and cross validation score is ', (accuracy_score(y_test,predgd)-scoregd.mean())*100)
print('\n')

print('extraTreesClassifier')
scoreet=cross_val_score(et,x,y)
print('Mean score is ',scoreet.mean()*100)
print('Accuracy score is ',accuracy_score(y_test,predet)*100)
print('Difference b/w accuracy score and cross validation score is ', (accuracy_score(y_test,predet)-scoreet.mean())*100)
print('\n')

print('Random forest')
scorerf=cross_val_score(rf,x,y)
print('Mean score is ',scorerf.mean()*100)
print('Accuracy score is ',accuracy_score(y_test,predrf)*100)
print('Difference b/w accuracy score and cross validation score is ', (accuracy_score(y_test,predrf)-scorerf.mean())*100)
print('\n')

print('adaboost')
scoread=cross_val_score(Ad,x,y)
print('Mean score is ',scoread.mean()*100)
print('Accuracy score is ',accuracy_score(y_test,predad)*100)
print('Difference b/w accuracy score and cross validation score is ', (accuracy_score(y_test,predad)-scoread.mean())*100)
print('\n')

print('Bagging')
scorebg=cross_val_score(bg,x,y)
print('Mean score is ',scorebg.mean()*100)
print('Accuracy score is ',accuracy_score(y_test,predbg)*100)
print('Difference b/w accuracy score and cross validation score is ', (accuracy_score(y_test,predbg)-scorebg.mean())*100)
# Out:
# Decision Tree classifier
# Mean score is  70.6320907617504
# Accuracy_score is  76.99784017278618
# Difference b/w accuracy score and cross validation score is  6.3657494110357815
#
#
# Support vector mission
# Mean score is  68.36304700162074
# Accuracy score is  71.05831533477321
# Difference b/w accuracy score and cross validation score is  2.6952683331524674
#
#
# GradientBoostingClassifier
# Mean score is  72.6094003241491
# Accuracy score is  79.48164146868251
# Difference b/w accuracy score and cross validation score is  6.8722411445333975
#
#
# extraTreesClassifier
# Mean score is  80.32414910858996
# Accuracy score is  87.79697624190065
# Difference b/w accuracy score and cross validation score is  7.472827133310689
#
#
# Random forest
# Mean score is  78.28200972447326
# Accuracy score is  85.85313174946005
# Difference b/w accuracy score and cross validation score is  7.571122024986787
#
#
# adaboost
# Mean score is  45.28363047001621
# ...

# %% [markdown]
# after applying the cross validation score for each model we can say that ExtraTreeClassifier model is performing good on my dataset
#
# so here we will choose the Extratreeclassifier to build the best model

# %%
from sklearn.model_selection import GridSearchCV

parameters={'criterion':['gini','entropy'],
           'random_state':[10,50,1000],
           'max_depth':[0,10,20],
           'n_jobs':[-2,-1,1],
           'n_estimators':[50,100,200,300]}

# %% [markdown]
# using the Hyperparameter to find the best parameters to perform the model very well

# %%
GCV=GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)

# %% [markdown]
# by seeing the all the model performance we can find ExtratreeClassifier is best model for this dataset and we can use the thing here to perform

# %%
GCV.fit(x_train,y_train)
GCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'n_estimators': 200,
#  'n_jobs': -2,
#  'random_state': 50}

# %% [markdown]
# sending the x_train and y_train through the Gridsearchcv to find best parameters of the ExtratreeClassifier

# %%
model=ExtraTreesClassifier(criterion='entropy',max_depth=20,random_state=50)

# %% [markdown]
# constructing the best model using the best parameter found by gridsearchcv

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('accuracy_score :',accuracy_score(y_test,pred)*100)
# Out:
# accuracy_score : 87.25701943844493

# %%
import pickle
filename='Red_wine.model'
pickle.dump(model,open(filename,'wb'))

# %% [markdown]
# to save the model import pickle lybrari

# %%
final_model=pickle.load(open('Red_wine.model','rb'))
final_model.score(x_test,y_test)
# Out:
# 0.8725701943844493

# %% [markdown]
# loading the saved model from my jupyter notebook and checking the score of my final saved model

# %% [markdown]
# conculation : ExtraTreesClassifier predicted well on datset
